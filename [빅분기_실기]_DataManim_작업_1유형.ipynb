# %% [markdown]
# <a href="https://colab.research.google.com/github/dduniverse/Bigdata_Analyst_Certificate/blob/main/%5B%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%8B%A4%EA%B8%B0%5D_DataManim_%EC%9E%91%EC%97%85_1%EC%9C%A0%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 작업 1유형
# https://www.datamanim.com/dataset/03_dataq/typeone.html

# %%
import pandas as pd

# %% [markdown]
# ## 유투브 인기동영상 데이터
# - 데이터 출처 :https://www.kaggle.com/rsrishav/youtube-trending-video-dataset?select=KR_youtube_trending_data.csv
# - 데이터 설명 : 유튜브 데일리 인기동영상 (한국)
# - dataurl : https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv',index_col=0)
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %% [markdown]
# ### Question 1
# 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)

# %%
# 'channelId' 빈도수 구하기(상위 10개)
df['channelId'].value_counts().head(10)
# Out:
# UCszFjh7CEfwDb7UUGb4RzCQ    372
# UClzB2iZ5jPoTNz0S-QU6Wiw    318
# UCtm_QoN2SIxwCE-59shX7Qg    318
# UCaKod3X1Tn4c7Ci0iUKcvzQ    313
# UCiwQRG2sCcfjKkgxMEdJGPg    293
# UChbE5OZQ6dRHECsX0tEPEZQ    283
# UCLkAepWjdylmXSltofFvsYQ    275
# UCQ2O-iftmnlfrBuNsUUTofQ    274
# UCtfriFvIe5gIe8wRWb8UTMg    258
# UCRuSxVu4iqTK5kCh90ntAgA    255
# Name: channelId, dtype: int64

# %%
# 빈도수 상위 10개 'channelId'의 index 구하기
df['channelId'].value_counts().head(10).index
# Out:
# Index(['UCszFjh7CEfwDb7UUGb4RzCQ', 'UClzB2iZ5jPoTNz0S-QU6Wiw',
#        'UCtm_QoN2SIxwCE-59shX7Qg', 'UCaKod3X1Tn4c7Ci0iUKcvzQ',
#        'UCiwQRG2sCcfjKkgxMEdJGPg', 'UChbE5OZQ6dRHECsX0tEPEZQ',
#        'UCLkAepWjdylmXSltofFvsYQ', 'UCQ2O-iftmnlfrBuNsUUTofQ',
#        'UCtfriFvIe5gIe8wRWb8UTMg', 'UCRuSxVu4iqTK5kCh90ntAgA'],
#       dtype='object')

# %%
# 'channelId'가 빈도수 상위 10개의 index인 channelTitle 구하기
df.loc[df['channelId'].isin(df['channelId'].value_counts().head(10).index)]['channelTitle']
# Out:
# 0                          장삐쭈
# 27                         총몇명
# 32                         파뿌리
# 76                          짤툰
# 79                         총몇명
#                  ...
# 60241                       짤툰
# 60242                      파뿌리
# 60271    엠뚜루마뚜루 : MBC 공식 종합 채널
# 60305          런닝맨 - 스브스 공식 채널
# 60327                      파뿌리
# Name: channelTitle, Length: 2959, dtype: object

# %%
# 'channelId'가 빈도수 상위 10개의 index인 channelTitle의 고유값 구하기
df.loc[df['channelId'].isin(df['channelId'].value_counts().head(10).index)]['channelTitle'].unique()
# Out:
# array(['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널',
#        '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV'],
#       dtype=object)

# %% [markdown]
# ### Question 2
# 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라

# %%
# 'dislikes'가 'likes'보다 큰 데이터의 'channelTitle' 찾기
df.loc[df['dislikes']>df['likes'],'channelTitle']
# Out:
# 1805             핫도그TV
# 2008             핫도그TV
# 2233             핫도그TV
# 2452             핫도그TV
# 2680             핫도그TV
#              ...
# 52344    Gen.G esports
# 52551    Gen.G esports
# 52554    Gen.G esports
# 52772    Gen.G esports
# 52776    Gen.G esports
# Name: channelTitle, Length: 143, dtype: object

# %%
# 'dislikes'가 'likes'보다 큰 데이터의 'channelTitle'의 고유값
df.loc[df['dislikes']>df['likes'],'channelTitle'].unique()
# Out:
# array(['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang',
#        '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담',
#        'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈',
#        '나혼자산다 STUDIO', 'Gen.G esports'], dtype=object)

# %% [markdown]
# ### Question 3
# 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라

# %%
# ['channelId','channelTitle']의 중복값 제거
df[['channelId','channelTitle']].drop_duplicates()[['channelId','channelTitle']]
# Out:
#                       channelId             channelTitle
# 0      UChbE5OZQ6dRHECsX0tEPEZQ                      장삐쭈
# 1      UCxXgIeE5hxWxHG6dz9Scg2w  RAIN's Official Channel
# 2      UCZUPZW5idAxYp-Asj__lVAA              서울시 · Seoul
# 3      UCT3CumbFIJiW33uq0UI3zlg             고기남자 MeatMan
# 4      UCdWgRSfttvDucq4ApcCg5Mw                    스브스밥집
# ...                         ...                      ...
# 60023  UCsiuN8Jco3LbbuTyGuqRgKg                      멸치형
# 60028  UCRnEWJKVc5FpC-9Z3CBt2ZQ          키키TV, 전지적 예능 시점
# 60035  UCkMN06eC97XL1qR1bExdwWg                    기용이tv
# 60036  UCp9G3sWsE42Qo9jgnB1ta2Q       INSSAOPPA G [인싸오빠]
# 60068  UCRCK5FCJtomQT3b88jXI_DA              한국닌텐도 공식 채널
#
# [1843 rows x 2 columns]

# %%
# ['channelId','channelTitle']의 중복값을 제거한 데이터의 'channelId'의 빈도수를 change로 저장
change=df[['channelId','channelTitle']].drop_duplicates()['channelId'].value_counts()
change
# Out:
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCuZu8NrpBG4WPXRi-hPBl-A    1
# UCDrAR1OWC2MD4s0JLetN0MA    1
# UCx2MVBsdTJ_sv0LiUpSQU2Q    1
# UCu2R3TCLSxYV8pRyBGNOh2g    1
# UCRCK5FCJtomQT3b88jXI_DA    1
# Name: channelId, Length: 1770, dtype: int64

# %%
# change의 값이 1 이상(=채널명을 바꾼 케이스)인 데이터 추출
change[change>1]
# Out:
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCk5bhZYNtbPJyNLRxN8D8NQ    2
# UCSiGNrrL2lAc0-_MfcUUUHA    2
# UCiBKp3KgsQCYT9Z2XxdBpbQ    2
# UCUEX0L7GHPs95m8S7G6kWVA    2
# UC-IYpdOqjkER7B6cnChwlhA    2
# Name: channelId, Length: 71, dtype: int64

# %%
len(change[change>1])
# Out:
# 71

# %% [markdown]
# ### Question 4
# 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?

# %%
# 'trending_date2'를 datetime 형식으로 바꾸기
df['trending_date2']=pd.to_datetime(df['trending_date2'])
df['trending_date2']
# Out:
# 0       2021-01-01
# 1       2021-01-01
# 2       2021-01-01
# 3       2021-01-01
# 4       2021-01-01
#            ...
# 60394   2021-10-19
# 60395   2021-10-19
# 60396   2021-10-19
# 60397   2021-10-19
# 60398   2021-10-19
# Name: trending_date2, Length: 60399, dtype: datetime64[ns]

# %%
# 요일로 바꾸기
df['trending_date2'].dt.day_name()
# Out:
# 0         Friday
# 1         Friday
# 2         Friday
# 3         Friday
# 4         Friday
#           ...
# 60394    Tuesday
# 60395    Tuesday
# 60396    Tuesday
# 60397    Tuesday
# 60398    Tuesday
# Name: trending_date2, Length: 60399, dtype: object

# %%
# 'Sunday'인 데이터의 'categoryId' 추출
df.loc[df['trending_date2'].dt.day_name()=='Sunday']['categoryId']
# Out:
# 400      24
# 401      22
# 402      10
# 403      24
# 404      24
#          ..
# 59994    10
# 59995    10
# 59996    10
# 59997    19
# 59998    24
# Name: categoryId, Length: 8600, dtype: int64

# %%
# 'Sunday'인 데이터의 'categoryId'의 빈도수 세기
df.loc[df['trending_date2'].dt.day_name()=='Sunday']['categoryId'].value_counts()
# Out:
# 24    3096
# 22    1337
# 10     830
# 17     636
# 23     556
# 25     437
# 26     363
# 20     289
# 1      274
# 15     217
# 27     199
# 28     167
# 2       99
# 19      91
# 29       9
# Name: categoryId, dtype: int64

# %%
# 내림차순으로 정렬된(기본값) 빈도수의 가장 첫번째 인덱스(=categoryId) 구하기
df.loc[df['trending_date2'].dt.day_name()=='Sunday']['categoryId'].value_counts().index[0]
# Out:
# 24

# %%
# 내림차순으로 정렬된(기본값) 빈도수의 가장 큰 값(=영상종류개수) 구하기
df.loc[df['trending_date2'].dt.day_name()=='Sunday']['categoryId'].value_counts().max()
# Out:
# 3096

# %% [markdown]
# ### Question 5
# 각 요일별 인기 영상들의 categoryId는 각각 몇개 씩인지 하나의 데이터 프레임으로 표현하라

# %%
# 'trending_date2'를 요일로 바꿔 'dayname'으로 저장
df['dayname']=df['trending_date2'].dt.day_name()

# %%
# 'dayname'과 'categoryId'로 그룹핑 후 데이터 개수 구하기
# series 형태로 출력됨
group=df.groupby(['dayname','categoryId']).size()
group
# Out:
# dayname    categoryId
# Friday     1             243
#            2             120
#            10            833
#            15            187
#            17            633
#                         ...
# Wednesday  25            468
#            26            385
#            27            212
#            28            165
#            29             12
# Length: 105, dtype: int64

# %%
# pivot_table을 만들기 위해 as_index=False를 해주어 dataframe 형태로 만들기
group=df.groupby(['dayname','categoryId'],as_index=False).size()
group
# Out:
#        dayname  categoryId  size
# 0       Friday           1   243
# 1       Friday           2   120
# 2       Friday          10   833
# 3       Friday          15   187
# 4       Friday          17   633
# ..         ...         ...   ...
# 100  Wednesday          25   468
# 101  Wednesday          26   385
# 102  Wednesday          27   212
# 103  Wednesday          28   165
# 104  Wednesday          29    12
#
# [105 rows x 3 columns]

# %%
# 'categoryId'를 index로, 'dayname'을 column으로 하는 pivot_table
group.pivot_table(index='categoryId',columns='dayname')
# Out:
#              size
# dayname    Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1             243    263      255    274      246     257       234
# 2             120    105      119     99      128     119       129
# 10            833    837      776    830      890     894       917
# 15            187    215      198    217      207     208       207
# 17            633    668      592    636      682     708       706
# 19             90     92       87     91       92      89        85
# 20            283    298      296    289      282     285       291
# 22           1288   1373     1289   1337     1341    1375      1333
# 23            568    594      570    556      560     569       566
# 24           2976   3148     3066   3096     2954    3084      3090
# 25            444    453      422    437      470     452       468
# 26            369    378      364    363      375     394       385
# ...

# %% [markdown]
# ### Question 6
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. viewcount대비 댓글수가 가장 높은 영상을 확인하라 (view_count값이 0인 경우는 제외한다)

# %%
# view_count가 0이 아닌 데이터의 'view_count','comment_count'를 df_view_comment로 저장
df_view_comment=df.loc[df['view_count']!=0,['view_count','comment_count']]
df_view_comment
# Out:
#        view_count  comment_count
# 0         1893473           8595
# 1         2600864          20129
# 2          347049            178
# 3          528458           3470
# 4          494904           3142
# ...           ...            ...
# 60394      538190           3117
# 60395     1607562           1141
# 60396     1125911           1915
# 60397     1741773            802
# 60398    13753485         195461
#
# [60386 rows x 2 columns]

# %%
# df_view_comment['comment_count']/df_view_comment['view_count']의 최댓값 구하기
max(df_view_comment['comment_count']/df_view_comment['view_count'])
# Out:
# 0.16151637633416135

# %%
# df_view_comment에서 df_view_comment['comment_count']/df_view_comment['view_count']값이 최댓값인 데이터 찾기 
df_view_comment.loc[df_view_comment['comment_count']/df_view_comment['view_count']==max(df_view_comment['comment_count']/df_view_comment['view_count'])]
# Out:
#        view_count  comment_count
# 50830     1214527         196166

# %%
# df_view_comment['comment_count']/df_view_comment['view_count']의 최댓값을 가지는 df_view_commet의 index를 answer_index로 저장
answer_index=df_view_comment.loc[df_view_comment['comment_count']/df_view_comment['view_count']==max(df_view_comment['comment_count']/df_view_comment['view_count'])].index
answer_index
# Out:
# Int64Index([50830], dtype='int64')

# %%
# df에서 index가 answer_index인 데이터의 title 찾기 
df.iloc[answer_index]['title']
# Out:
# 50830    60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)
# Name: title, dtype: object

# %% [markdown]
# ### Question 7
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다.viewcount대비 댓글수가 가장 낮은 영상을 확인하라 (view_counts, ratio값이 0인경우는 제외한다.)

# %%
df_view_comment2=df.loc[(df['view_count']!=0) & (df['comment_count']!=0),['view_count','comment_count']]
df_view_comment2
# Out:
#        view_count  comment_count
# 0         1893473           8595
# 1         2600864          20129
# 2          347049            178
# 3          528458           3470
# 4          494904           3142
# ...           ...            ...
# 60394      538190           3117
# 60395     1607562           1141
# 60396     1125911           1915
# 60397     1741773            802
# 60398    13753485         195461
#
# [59609 rows x 2 columns]

# %%
# df_view_comment['comment_count']/df_view_comment['view_count']의 최솟값 구하기
min(df_view_comment2['comment_count']/df_view_comment2['view_count'])
# Out:
# 2.152455727052944e-08

# %%
# df_view_comment에서 df_view_comment['comment_count']/df_view_comment['view_count']값이 최솟값 데이터 찾기 
df_view_comment2.loc[df_view_comment2['comment_count']/df_view_comment['view_count']==min(df_view_comment2['comment_count']/df_view_comment2['view_count'])]
# Out:
#        view_count  comment_count
# 46005    46458563              1

# %%
# df_view_comment['comment_count']/df_view_comment['view_count']의 최솟값을 가지는 df_view_commet의 index를 answer_index로 저장
answer_index=df_view_comment2.loc[df_view_comment2['comment_count']/df_view_comment['view_count']==min(df_view_comment2['comment_count']/df_view_comment2['view_count'])].index
answer_index
# Out:
# Int64Index([46005], dtype='int64')

# %%
# df에서 index가 answer_index인 데이터의 title 찾기 
df.iloc[answer_index]['title']
# Out:
# 46005    Join the BTS #PermissiontoDance Challenge only...
# Name: title, dtype: object

# %% [markdown]
# ### Question 8
# like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인경우는 제외한다)

# %%
# 'likes'와 'dislikes'가 모두 0이 아닌 데이터의 'likes'와 'dislikes'를 df_like로 저장
df_like=df.loc[(df['likes']!=0) & (df['dislikes']!=0)][['likes','dislikes']]
df_like
# Out:
#          likes  dislikes
# 0        38249       730
# 2         3564       120
# 3        15372       280
# 4         3918       111
# 5        26660       368
# ...        ...       ...
# 60394    16671       209
# 60395    14615       258
# 60396    26490       263
# 60397    14994       304
# 60398  1784532      9737
#
# [59693 rows x 2 columns]

# %%
# df_like['dislikes']/df_like['likes']의 최솟값
min(df_like['dislikes']/df_like['likes'])
# Out:
# 0.0005234505862646566

# %%
# df_like에서 df_like['dislikes']/df_like['likes']의 최솟값을 가지는 데이터의 index를 answer_index로 저장
answer_index=df_like.loc[df_like['dislikes']/df_like['likes']==min(df_like['dislikes']/df_like['likes'])].index
answer_index
# Out:
# Int64Index([11477], dtype='int64')

# %%
# df에서 answer_index 행의 title 출력
df.iloc[answer_index]['title']
# Out:
# 11477    [줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가...
# Name: title, dtype: object

# %% [markdown]
# ### Question 9
# 가장많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)

# %%
# 'channelTitle'의 빈도수 구하기
df['channelTitle'].value_counts()
# Out:
# 짤툰                       372
# 파뿌리                      318
# SPOTV                    318
# 런닝맨 - 스브스 공식 채널          313
# 엠뚜루마뚜루 : MBC 공식 종합 채널    293
#                         ...
# NamSeok Byun               1
# 공원생활 / ParkLife            1
# Brave Girls                1
# 깽냥툰 KY'T                   1
# 알파                         1
# Name: channelTitle, Length: 1832, dtype: int64

# %%
# 첫번째 데이터 출력
df['channelTitle'].value_counts().index[0]
# Out:
# '짤툰'

# %% [markdown]
# ### Question 10
# 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?

# %%
# 'title','channelId'의 빈도수가 20이상인 데이터 찾기
df[['title','channelId']].value_counts()>=20
# Out:
# title                                                           channelId
# 컵라면 먹을 때 절대 일어날리 없는 상황들 ㅋㅋㅋ                                     UCmzMtXrJgfCqA0rfhz8_P4A     True
# 대한민국 VS 투르크메니스탄 : FIFA 카타르 월드컵 2차 예선 하이라이트 - 2021.06.05         UCpjOmwiy88a9EV3Rv8ukJgw     True
# 극과 극을 살고 있는 인도의 갑부와 빈곤층들!                                       UCi9Sl8GnFdYoqEVXnojBPJw     True
# 2주더놀릴예정                                                         UCaKod3X1Tn4c7Ci0iUKcvzQ     True
# 대박... 멧돼지를 아들로 삼은 할아버지｜KBS 주주클럽 050410 방송                       UCAhKKbDO9-ymWZ_7iAFLBQQ     True
#                                                                                             ...
# 천재 친구 황봉황 [총몇명 스토리2]                                            UCRuSxVu4iqTK5kCh90ntAgA    False
# 담배충 [병맛더빙/웃긴영상]                                                 UCUK4YjvUvHrFQwTFXwkUIng    False
# Official Trailer | The Falcon and The Winter Soldier | Disney+  UCvC4D8onUfXzvjTOM-dBfEA    False
# ...

# %%
# True인 데이터의 개수 찾기(true=1이므로 sum하면 갯수가 됨)
(df[['title','channelId']].value_counts()>=20).sum()
# Out:
# 40

# %% [markdown]
# ## 유튜브 공범컨텐츠 동영상 데이터
# - 데이터 출처 :https://www.kaggle.com/kukuroo3/youtube-episodic-contents-kr(참고, 데이터 수정)
# - 데이터 설명 : 유튜브 “공범” 컨텐츠 동영상 정보 ( 10분 간격 수집)
# - dataurl1 (비디오 정보) = https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/videoInfo.csv
# - dataurl2 (참가자 채널 정보)= https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/channelInfo.csv

# %%
import pandas as pd

channel =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/channelInfo.csv')
video =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/videoInfo.csv')

display(channel.head())
display(video.head())
# Out:
#                   channelid   subcnt    viewcnt  videocnt  \
# 0  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  410238653       736
# 1  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       736
# 2  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       735
# 3  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       737
# 4  UCkQCwnkQfgSuPTTnw_Y7v7w  1320000  412531322       737
#
#                     ct channelname
# 0  2021-09-30 03:01:03         꽈뚜룹
# 1  2021-09-30 09:01:03         꽈뚜룹
# 2  2021-09-30 15:01:03         꽈뚜룹
# 3  2021-09-30 21:01:03         꽈뚜룹
# 4  2021-10-01 03:01:04         꽈뚜룹
#        videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 0  c5JQp6xafqc  1667010    30474         706            0   6587
# 1  c5JQp6xafqc  1669089    30495         707            0   6589
# 2  c5JQp6xafqc  1674759    30522         711            0   6596
# 3  c5JQp6xafqc  1677026    30555         712            0   6604
# 4  c5JQp6xafqc  1681824    30585         713            0   6600
#
# ...

# %% [markdown]
# ### Question 1
# 각 데이터의 ‘ct’컬럼을 시간으로 인식할수 있게 datatype을 변경하고 video 데이터의 videoname의 각 value 마다 몇개의 데이터씩 가지고 있는지 확인하라

# %%
channel['ct']=pd.to_datetime(channel['ct'])
channel['ct']
# Out:
# 0      2021-09-30 03:01:03
# 1      2021-09-30 09:01:03
# 2      2021-09-30 15:01:03
# 3      2021-09-30 21:01:03
# 4      2021-10-01 03:01:04
#                ...
# 1390   2021-10-31 15:01:04
# 1391   2021-10-31 21:01:04
# 1392   2021-11-01 03:01:03
# 1393   2021-11-01 09:01:04
# 1394   2021-11-01 15:01:07
# Name: ct, Length: 1395, dtype: datetime64[ns]

# %%
video['ct']=pd.to_datetime(video['ct'])
video['ct']
# Out:
# 0       2021-10-10 15:20:03
# 1       2021-10-10 15:30:03
# 2       2021-10-10 15:40:02
# 3       2021-10-10 15:50:03
# 4       2021-10-10 16:00:03
#                 ...
# 15196   2021-11-01 14:50:06
# 15197   2021-11-01 15:00:05
# 15198   2021-11-01 15:10:05
# 15199   2021-11-01 15:20:04
# 15200   2021-11-01 15:30:05
# Name: ct, Length: 15201, dtype: datetime64[ns]

# %%
video['videoname'].value_counts()
# Out:
#  공범 EP1    3492
#  공범 EP2    3204
#  공범 EP3    2568
#  공범 EP4    2280
#  공범 EP5    1562
#  공범 EP6    1274
#  공범 EP7     555
#  공범 EP8     266
# Name: videoname, dtype: int64

# %% [markdown]
# ### Question 2
# 수집된 각 video의 가장 최신화 된 날짜의 viewcount값을 출력하라

# %%
# ['videoname','ct']순으로 video 데이터 정렬
video.sort_values(['videoname','ct'])
# Out:
#            videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 10     c5JQp6xafqc     6396      680           3            0    226
# 11     c5JQp6xafqc    13087     1113           7            0    273
# 12     c5JQp6xafqc    19991     1446          12            0    363
# 13     c5JQp6xafqc    27451     1859          19            0    479
# 14     c5JQp6xafqc    36559     2306          23            0    602
# ...            ...      ...      ...         ...          ...    ...
# 15196  yZt-h-KcmUE  1285474    25582        3615            0  31603
# 15197  yZt-h-KcmUE  1286376    25592        3617            0  31627
# 15198  yZt-h-KcmUE  1287172    25597        3619            0  31643
# 15199  yZt-h-KcmUE  1288138    25606        3619            0  31648
# 15200  yZt-h-KcmUE  1289088    25616        3621            0  31663
#
#                        ct videoname
# 10    2021-10-07 19:10:03    공범 EP1
# 11    2021-10-07 19:20:02    공범 EP1
# ...

# %%
# ['videoname','ct']순으로 video 데이터 정렬 후 videoname이 중복되는 것 제거하되 마지막 데이터만 남김
video.sort_values(['videoname','ct']).drop_duplicates('videoname',keep='last')
# Out:
#            videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 3491   c5JQp6xafqc  3180532    41043        1113            0   7674
# 6695   23QQ1ru9YQg  2199328    25566         763            0   9171
# 9263   GygoAk1hDU0  1671294    22719         508            0  12499
# 11543  bK0_3Vbfvs8  1818493    22703         408            0  16949
# 13105  hv7FBjskAu0  1503435    19926         421            0  12434
# 14934  AxGKHmXyuAE  1750222    24494         389            0  13025
# 13660  QUjQbgj5IXM  1630200    29335         400            0  18247
# 15200  yZt-h-KcmUE  1289088    25616        3621            0  31663
#
#                        ct videoname
# 3491  2021-11-01 15:30:03    공범 EP1
# 6695  2021-11-01 15:30:03    공범 EP2
# 9263  2021-11-01 15:30:03    공범 EP3
# 11543 2021-11-01 15:30:03    공범 EP4
# 13105 2021-11-01 15:30:04    공범 EP5
# 14934 2021-11-01 15:30:04    공범 EP6
# 13660 2021-11-01 15:30:05    공범 EP7
# 15200 2021-11-01 15:30:05    공범 EP8

# %%
# ['viewcnt','videoname','ct']만 가져오기
video.sort_values(['videoname','ct']).drop_duplicates('videoname',keep='last')[['viewcnt','videoname','ct']]
# Out:
#        viewcnt videoname                  ct
# 3491   3180532    공범 EP1 2021-11-01 15:30:03
# 6695   2199328    공범 EP2 2021-11-01 15:30:03
# 9263   1671294    공범 EP3 2021-11-01 15:30:03
# 11543  1818493    공범 EP4 2021-11-01 15:30:03
# 13105  1503435    공범 EP5 2021-11-01 15:30:04
# 14934  1750222    공범 EP6 2021-11-01 15:30:04
# 13660  1630200    공범 EP7 2021-11-01 15:30:05
# 15200  1289088    공범 EP8 2021-11-01 15:30:05

# %%
# 결과가 동일하기 나오기 위해 인덱스를 초기화 시킴
video.sort_values(['videoname','ct']).drop_duplicates('videoname',keep='last')[['viewcnt','videoname','ct']].reset_index(drop=True)
# Out:
#    viewcnt videoname                  ct
# 0  3180532    공범 EP1 2021-11-01 15:30:03
# 1  2199328    공범 EP2 2021-11-01 15:30:03
# 2  1671294    공범 EP3 2021-11-01 15:30:03
# 3  1818493    공범 EP4 2021-11-01 15:30:03
# 4  1503435    공범 EP5 2021-11-01 15:30:04
# 5  1750222    공범 EP6 2021-11-01 15:30:04
# 6  1630200    공범 EP7 2021-11-01 15:30:05
# 7  1289088    공범 EP8 2021-11-01 15:30:05

# %% [markdown]
# ### Question 3
# Channel 데이터중 2021-10-03일 이후 각 채널의 처음 기록 됐던 구독자 수(subcnt)를 출력하라

# %%
# 2021-10-03 이후 데이터의 ['channelname','subcnt']를 가져옴
# channelname이 중복되는 것은 제외하되 첫번째 데이터만 남김(처음 기록된 구독자 수를 구해야 함)
# 결과와 같게 출력하기 위해 인덱스 초기화
channel[channel['ct']>'2021-10-03'][['channelname','subcnt']].drop_duplicates('channelname',keep='first').reset_index(drop=True)
# Out:
#         channelname   subcnt
# 0               꽈뚜룹  1330000
# 1             야전삽짱재   257000
# 2        츄정ChuJeong   322000
# 3            논리왕 전기   922000
# 4   와글와글 WagleWagle    55000
# 5               조나단   215000
# 6           형사!탐정되다    14900
# 7        김농밀의 농밀한 삶     7520
# 8       릴펄 Lilpearl    10100
# 9     곽토리 kwak tori   471000
# 10    Balming Tiger    54300

# %% [markdown]
# ### Question 4
# 각채널의 2021-10-03 03:00:00 ~ 2021-11-01 15:00:00 까지 구독자수 (subcnt) 의 증가량을 구하여라

# %%
# 2021-10-03 03:00:00 ~ 2021-11-01 15:00:00 까지의 channel 데이터를 channel_s로 저장
channel_s=channel[('2021-10-03 03'<channel['ct'])&(channel['ct']<='2021-11-01 15')]

# %%
# channel_s를 channelname으로 그룹핑하여 subcnt의 처음, 마지막 값을 구해 channel_s_group으로 저장
channel_s_group=channel_s.groupby('channelname')['subcnt'].agg(['first','last'])
channel_s_group
# Out:
#                    first     last
# channelname
# Balming Tiger      54300    56800
# 곽토리 kwak tori     471000   469000
# 김농밀의 농밀한 삶          7520     9060
# 꽈뚜룹              1330000  1400000
# 논리왕 전기            922000   911000
# 릴펄 Lilpearl        10100    21100
# 야전삽짱재             257000   268000
# 와글와글 WagleWagle    55000    55000
# 조나단               215000   227000
# 츄정ChuJeong        322000   323000
# 형사!탐정되다            14900    25200

# %%
# last-first를 통해 subcnt의 증가량을 구해 del 컬럼으로 저장
channel_s_group['del']=channel_s_group['last']-channel_s_group['first']
channel_s_group
# Out:
#                    first     last    del
# channelname
# Balming Tiger      54300    56800   2500
# 곽토리 kwak tori     471000   469000  -2000
# 김농밀의 농밀한 삶          7520     9060   1540
# 꽈뚜룹              1330000  1400000  70000
# 논리왕 전기            922000   911000 -11000
# 릴펄 Lilpearl        10100    21100  11000
# 야전삽짱재             257000   268000  11000
# 와글와글 WagleWagle    55000    55000      0
# 조나단               215000   227000  12000
# 츄정ChuJeong        322000   323000   1000
# 형사!탐정되다            14900    25200  10300

# %%
# 결과와 같게 나오기 위해 index를 초기화하고 기존 인덱스인 channelname은 삭제하지 않음
# channelname과 del 출력
channel_s_group.reset_index(drop=False,inplace=True)
channel_s_group[['channelname','del']]
# Out:
#         channelname    del
# 0     Balming Tiger   2500
# 1     곽토리 kwak tori  -2000
# 2        김농밀의 농밀한 삶   1540
# 3               꽈뚜룹  70000
# 4            논리왕 전기 -11000
# 5       릴펄 Lilpearl  11000
# 6             야전삽짱재  11000
# 7   와글와글 WagleWagle      0
# 8               조나단  12000
# 9        츄정ChuJeong   1000
# 10          형사!탐정되다  10300

# %% [markdown]
# ### Question 5
# 각 비디오는 10분 간격으로 구독자수, 좋아요, 싫어요수, 댓글수가 수집된것으로 알려졌다. 공범 EP1의 비디오정보 데이터중 수집간격이 5분 이하, 20분이상인 데이터 구간( 해당 시점 전,후) 의 시각을 모두 출력하라

# %%
# videoname에 '공범 EP1'이 포함된 데이터를 'ct'순으로 정렬하려 ep1에 저장
ep1=video[video['videoname'].str.contains('공범 EP1')].sort_values('ct')
ep1
# Out:
#           videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 10    c5JQp6xafqc     6396      680           3            0    226
# 11    c5JQp6xafqc    13087     1113           7            0    273
# 12    c5JQp6xafqc    19991     1446          12            0    363
# 13    c5JQp6xafqc    27451     1859          19            0    479
# 14    c5JQp6xafqc    36559     2306          23            0    602
# ...           ...      ...      ...         ...          ...    ...
# 3487  c5JQp6xafqc  3179698    41040        1113            0   7673
# 3488  c5JQp6xafqc  3179971    41042        1113            0   7673
# 3489  c5JQp6xafqc  3179971    41042        1113            0   7673
# 3490  c5JQp6xafqc  3180332    41043        1113            0   7674
# 3491  c5JQp6xafqc  3180532    41043        1113            0   7674
#
#                       ct videoname
# 10   2021-10-07 19:10:03    공범 EP1
# 11   2021-10-07 19:20:02    공범 EP1
# 12   2021-10-07 19:30:03    공범 EP1
# ...

# %%
import datetime

# ep1의 ct열을 앞뒤 1행과 차분했을 때 5분이하 또는 20분 이상인 데이터 찾기
ep1[(ep1['ct'].diff(1)<=datetime.timedelta(minutes=5)) | (ep1['ct'].diff(1)>=datetime.timedelta(minutes=20))]
# Out:
#           videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 721   c5JQp6xafqc  2228250    34559         849            0   7191
# 722   c5JQp6xafqc  2228250    34559         849            0   7191
# 1636  c5JQp6xafqc  2707933    37901         988            0   7410
#
#                       ct videoname
# 721  2021-10-13 09:41:37    공범 EP1
# 722  2021-10-13 09:41:37    공범 EP1
# 1636 2021-10-19 18:20:03    공범 EP1

# %%
# 721,722,1636행의 전후 행 출력하기
ep1[ep1.index.isin([720,721,722,723,1635,1636,1637])]
# Out:
#           videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 720   c5JQp6xafqc  2153676    34104         830            0   7120
# 721   c5JQp6xafqc  2228250    34559         849            0   7191
# 722   c5JQp6xafqc  2228250    34559         849            0   7191
# 723   c5JQp6xafqc  2228669    34566         849            0   7194
# 1635  c5JQp6xafqc  2706691    37893         987            0   7410
# 1636  c5JQp6xafqc  2707933    37901         988            0   7410
# 1637  c5JQp6xafqc  2708448    37903         988            0   7410
#
#                       ct videoname
# 720  2021-10-12 19:20:03    공범 EP1
# 721  2021-10-13 09:41:37    공범 EP1
# 722  2021-10-13 09:41:37    공범 EP1
# 723  2021-10-13 09:50:03    공범 EP1
# 1635 2021-10-19 17:50:02    공범 EP1
# 1636 2021-10-19 18:20:03    공범 EP1
# 1637 2021-10-19 18:30:03    공범 EP1

# %% [markdown]
# ### Question 6
# 각 에피소드의 시작날짜(년-월-일)를 에피소드 이름과 묶어 데이터 프레임으로 만들고 출력하라

# %%
# video의 ['ct','videoname']을 정렬하여 중복데이터의 첫번째만 남기고 제거.
first_video=video[['ct','videoname']].sort_values(['ct','videoname']).drop_duplicates('videoname',keep='first')
first_video
# Out:
#                        ct videoname
# 10    2021-10-07 19:10:03    공범 EP1
# 3496  2021-10-09 19:10:03    공범 EP2
# 6696  2021-10-14 19:10:04    공범 EP3
# 9264  2021-10-16 19:10:04    공범 EP4
# 11544 2021-10-21 19:10:04    공범 EP5
# 13661 2021-10-23 19:10:04    공범 EP6
# 13106 2021-10-28 19:10:04    공범 EP7
# 14935 2021-10-30 19:20:04    공범 EP8

# %%
# 'ct' 컬럼의 '년-월-일'을 date컬럼으로 저장
first_video['date']=first_video['ct'].dt.date
first_video
# Out:
#                        ct videoname        date
# 10    2021-10-07 19:10:03    공범 EP1  2021-10-07
# 3496  2021-10-09 19:10:03    공범 EP2  2021-10-09
# 6696  2021-10-14 19:10:04    공범 EP3  2021-10-14
# 9264  2021-10-16 19:10:04    공범 EP4  2021-10-16
# 11544 2021-10-21 19:10:04    공범 EP5  2021-10-21
# 13661 2021-10-23 19:10:04    공범 EP6  2021-10-23
# 13106 2021-10-28 19:10:04    공범 EP7  2021-10-28
# 14935 2021-10-30 19:20:04    공범 EP8  2021-10-30

# %%
# date와 videoname 출력
first_video[['date','videoname']]
# Out:
#              date videoname
# 10     2021-10-07    공범 EP1
# 3496   2021-10-09    공범 EP2
# 6696   2021-10-14    공범 EP3
# 9264   2021-10-16    공범 EP4
# 11544  2021-10-21    공범 EP5
# 13661  2021-10-23    공범 EP6
# 13106  2021-10-28    공범 EP7
# 14935  2021-10-30    공범 EP8

# %% [markdown]
# ### Question 7
# “공범” 컨텐츠의 경우 19:00시에 공개 되는것으로 알려져있다. 공개된 날의 21시의 viewcnt, ct, videoname 으로 구성된 데이터 프레임을 viewcnt를 내림차순으로 정렬하여 출력하라

# %%
# 'ct' 컬럼의 시간을 'hour'컬럼으로 저장
video['hour']=video['ct'].dt.hour
video['hour']
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        16
#          ..
# 15196    14
# 15197    15
# 15198    15
# 15199    15
# 15200    15
# Name: hour, Length: 15201, dtype: int64

# %%
# 21시 데이터를 ['videoname','ct']순으로 정렬
video[video['hour']==21].sort_values(['videoname','ct'])
# Out:
#            videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 21     c5JQp6xafqc   117340     6032          69            0   1409
# 22     c5JQp6xafqc   129841     6519          83            0   1522
# 23     c5JQp6xafqc   139487     7004         105            0   1627
# 24     c5JQp6xafqc   147763     7444         112            0   1701
# 25     c5JQp6xafqc   159899     7861         117            0   1803
# ...            ...      ...      ...         ...          ...    ...
# 15090  yZt-h-KcmUE  1159021    24543        3446            0  30092
# 15091  yZt-h-KcmUE  1161886    24568        3446            0  30131
# 15092  yZt-h-KcmUE  1165092    24591        3447            0  30165
# 15093  yZt-h-KcmUE  1167818    24614        3450            0  30185
# 15094  yZt-h-KcmUE  1170183    24633        3453            0  30220
#
#                        ct videoname  hour
# 21    2021-10-07 21:00:03    공범 EP1    21
# 22    2021-10-07 21:10:03    공범 EP1    21
# ...

# %%
# 21시 데이터를 ['videoname','ct']순으로 정렬한 후 'videoname'이 중복되는 데이터를 첫번째만 남기고 삭제하여 video_21로 저장
video_21=video[video['hour']==21].sort_values(['videoname','ct']).drop_duplicates('videoname',keep='first')
video_21
# Out:
#            videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 21     c5JQp6xafqc   117340     6032          69            0   1409
# 3507   23QQ1ru9YQg   148144     6039         122            0   2127
# 6707   GygoAk1hDU0   147183     5839          76            0   3105
# 9275   bK0_3Vbfvs8   217674     7854          82            0   5029
# 11555  hv7FBjskAu0   201179     6897         105            0   4283
# 13672  AxGKHmXyuAE   213899     8259          79            0   4325
# 13117  QUjQbgj5IXM   252032    11111          90            0   6395
# 14945  yZt-h-KcmUE   264029    11598        1438            0  13292
#
#                        ct videoname  hour
# 21    2021-10-07 21:00:03    공범 EP1    21
# 3507  2021-10-09 21:00:03    공범 EP2    21
# 6707  2021-10-14 21:00:04    공범 EP3    21
# 9275  2021-10-16 21:00:04    공범 EP4    21
# 11555 2021-10-21 21:00:04    공범 EP5    21
# 13672 2021-10-23 21:00:06    공범 EP6    21
# 13117 2021-10-28 21:00:04    공범 EP7    21
# ...

# %%
# video_21의 ['videoname','viewcnt','ct'] 컬럼을 viewcnt 기준 내림차순으로 정렬
# 결과와 같게 출력하기 위해 index 초기화
video_21[['videoname','viewcnt','ct']].sort_values('viewcnt',ascending=False).reset_index(drop=True)
# Out:
#   videoname  viewcnt                  ct
# 0    공범 EP8   264029 2021-10-30 21:00:08
# 1    공범 EP7   252032 2021-10-28 21:00:04
# 2    공범 EP4   217674 2021-10-16 21:00:04
# 3    공범 EP6   213899 2021-10-23 21:00:06
# 4    공범 EP5   201179 2021-10-21 21:00:04
# 5    공범 EP2   148144 2021-10-09 21:00:03
# 6    공범 EP3   147183 2021-10-14 21:00:04
# 7    공범 EP1   117340 2021-10-07 21:00:03

# %% [markdown]
# ### Question 8
# video 정보의 가장 최근 데이터들에서 각 에피소드의 싫어요/좋아요 비율을 ratio 컬럼으로 만들고 videoname, ratio로 구성된 데이터 프레임을 ratio를 오름차순으로 정렬하라

# %%
# ct기준 오름차순 정렬 후 videoname이 중복되는 데이터는 마지막만 남기고 삭제하여 last_video로 저장
last_video=video.sort_values('ct').drop_duplicates('videoname',keep='last')
last_video
# Out:
#            videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 11543  bK0_3Vbfvs8  1818493    22703         408            0  16949
# 3491   c5JQp6xafqc  3180532    41043        1113            0   7674
# 9263   GygoAk1hDU0  1671294    22719         508            0  12499
# 6695   23QQ1ru9YQg  2199328    25566         763            0   9171
# 13105  hv7FBjskAu0  1503435    19926         421            0  12434
# 14934  AxGKHmXyuAE  1750222    24494         389            0  13025
# 13660  QUjQbgj5IXM  1630200    29335         400            0  18247
# 15200  yZt-h-KcmUE  1289088    25616        3621            0  31663
#
#                        ct videoname  hour
# 11543 2021-11-01 15:30:03    공범 EP4    15
# 3491  2021-11-01 15:30:03    공범 EP1    15
# 9263  2021-11-01 15:30:03    공범 EP3    15
# 6695  2021-11-01 15:30:03    공범 EP2    15
# 13105 2021-11-01 15:30:04    공범 EP5    15
# 14934 2021-11-01 15:30:04    공범 EP6    15
# 13660 2021-11-01 15:30:05    공범 EP7    15
# ...

# %%
# last_video에서 dislikecnt/likecnt 값을 ratio 컬럼에 저장
last_video['ratio']=last_video['dislikecnt']/last_video['likecnt']
last_video['ratio']
# Out:
# 11543    0.017971
# 3491     0.027118
# 9263     0.022360
# 6695     0.029844
# 13105    0.021128
# 14934    0.015881
# 13660    0.013636
# 15200    0.141357
# Name: ratio, dtype: float64

# %%
# videoname과 ratio를 ratio 기준으로 오름차순 정렬하여 출력
last_video[['videoname','ratio']].sort_values('ratio').reset_index(drop=True)
# Out:
#   videoname     ratio
# 0    공범 EP7  0.013636
# 1    공범 EP6  0.015881
# 2    공범 EP4  0.017971
# 3    공범 EP5  0.021128
# 4    공범 EP3  0.022360
# 5    공범 EP1  0.027118
# 6    공범 EP2  0.029844
# 7    공범 EP8  0.141357

# %% [markdown]
# ### Question 9
# 2021-11-01 00:00:00 ~ 15:00:00까지 각 에피소드별 viewcnt의 증가량을 데이터 프레임으로 만드시오

# %%
# 2021-11-01 00:00:00 ~ 15:00:00까지 ['videoname','viewcnt'] 데이터를 video_1101로 저장
video_1101=video.loc[('2021-11-01 00' <= video['ct']) & (video['ct']<='2021-11-01 15'),['videoname','viewcnt']]
video_1101
# Out:
#       videoname  viewcnt
# 3398     공범 EP1  3166400
# 3399     공범 EP1  3166721
# 3400     공범 EP1  3167110
# 3401     공범 EP1  3167459
# 3402     공범 EP1  3167809
# ...         ...      ...
# 15192    공범 EP8  1281140
# 15193    공범 EP8  1282186
# 15194    공범 EP8  1283259
# 15195    공범 EP8  1284443
# 15196    공범 EP8  1285474
#
# [720 rows x 2 columns]

# %%
# video_1101을 videoname으로 그룹핑한 후 viewcnt의 처음, 마지막 값을 구함
video_1101_group=video_1101.groupby('videoname')['viewcnt'].agg(['first','last'])
video_1101_group
# Out:
#              first     last
# videoname
#  공범 EP1    3166400  3179698
#  공범 EP2    2188578  2198878
#  공범 EP3    1660916  1670843
#  공범 EP4    1808141  1817965
#  공범 EP5    1492223  1503047
#  공범 EP6    1735457  1749598
#  공범 EP7    1602201  1629150
#  공범 EP8    1196327  1285474

# %%
# 마지막-처음 값을 viewcnt 컬럼으로 저장
video_1101_group['viewcnt']=video_1101_group['last']-video_1101_group['first']
video_1101_group
# Out:
#              first     last  viewcnt
# videoname
#  공범 EP1    3166400  3179698    13298
#  공범 EP2    2188578  2198878    10300
#  공범 EP3    1660916  1670843     9927
#  공범 EP4    1808141  1817965     9824
#  공범 EP5    1492223  1503047    10824
#  공범 EP6    1735457  1749598    14141
#  공범 EP7    1602201  1629150    26949
#  공범 EP8    1196327  1285474    89147

# %%
video_1101_group['viewcnt']
# Out:
# videoname
#  공범 EP1    13298
#  공범 EP2    10300
#  공범 EP3     9927
#  공범 EP4     9824
#  공범 EP5    10824
#  공범 EP6    14141
#  공범 EP7    26949
#  공범 EP8    89147
# Name: viewcnt, dtype: int64

# %% [markdown]
# ### Question 10
# video 데이터 중에서 중복되는 데이터가 존재한다. 중복되는 각 데이터의 시간대와 videoname 을 구하여라

# %%
# video에서 중복되는 행 찾기
video.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15196    False
# 15197    False
# 15198    False
# 15199    False
# 15200    False
# Length: 15201, dtype: bool

# %%
# 중복되는 행의 데이터 확인
video[video.duplicated()]
# Out:
#           videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 722   c5JQp6xafqc  2228250    34559         849            0   7191
# 3927  23QQ1ru9YQg  1408005    20484         554            0   8567
#
#                       ct videoname  hour
# 722  2021-10-13 09:41:37    공범 EP1     9
# 3927 2021-10-13 09:41:37    공범 EP2     9

# %%
# 중복되는 행의 videoname과 ct 확인
video[video.duplicated()][['videoname','ct']]
# Out:
#      videoname                  ct
# 722     공범 EP1 2021-10-13 09:41:37
# 3927    공범 EP2 2021-10-13 09:41:37

# %% [markdown]
# ## 월드컵 출전선수 골기록 데이터
# - 데이터 출처 :https://www.kaggle.com/darinhawley/fifa-world-cup-goalscorers-19302018(참고, 데이터 수정)
# - 데이터 설명 : 1930 ~2018년도 월드컵 출전선수 골기록
# - data url = https://raw.githubusercontent.com/Datamanim/datarepo/main/worldcup/worldcupgoals.csv

# %%
import pandas as pd

df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/worldcup/worldcupgoals.csv')
df
# Out:
#                    Player  Goals                Years     Country
# 0          Miroslav Klose     16  2002-2006-2010-2014     Germany
# 1                 Ronaldo     15       1998-2002-2006      Brazil
# 2             Gerd Muller     14            1970-1974     Germany
# 3           Just Fontaine     13                 1958      France
# 4                    Pele     12  1958-1962-1966-1970      Brazil
# ...                   ...    ...                  ...         ...
# 1290        Josip Skoblar      1                 1962  Yugoslavia
# 1291          Safet Susic      1            1982-1990  Yugoslavia
# 1292  Aleksandar Tirnanic      1                 1930  Yugoslavia
# 1293  Djordje Vujadinovic      1                 1930  Yugoslavia
# 1294         Branko Zebec      1            1954-1958  Yugoslavia
#
# [1295 rows x 4 columns]

# %% [markdown]
# ### Question 1
# 주어진 전체 기간의 각 나라별 골득점수 상위 5개 국가와 그 득점수를 데이터프레임형태로 출력하라

# %%
# 'Country'를 기준으로 그룹핑 후 'Goals' 합을 구한 데이터프레임을 df_country로 저장
df_country=df.groupby('Country')['Goals'].sum().reset_index()
df_country
# Out:
#        Country  Goals
# 0      Algeria     13
# 1       Angola      1
# 2    Argentina    135
# 3    Australia     13
# 4      Austria     40
# ..         ...    ...
# 71        USSR     52
# 72     Ukraine      5
# 73     Uruguay     86
# 74       Wales      4
# 75  Yugoslavia     61
#
# [76 rows x 2 columns]

# %%
# df_country를 'Goals' 기준으로 내림차순으로 정렬
df_country.sort_values('Goals',ascending=False).head()
# Out:
#       Country  Goals
# 8      Brazil    228
# 25    Germany    226
# 2   Argentina    135
# 36      Italy    123
# 24     France    115

# %%
# 결과와 같게 나오기 위해 'Country'를 index로 설정
df_country.sort_values('Goals',ascending=False).head().set_index('Country')
# Out:
#            Goals
# Country
# Brazil       228
# Germany      226
# Argentina    135
# Italy        123
# France       115

# %% [markdown]
# ### Question 2
# 주어진 전체기간동안 골득점을 한 선수가 가장 많은 나라 상위 5개 국가와 그 선수 숫자를 데이터 프레임 형식으로 출력하라

# %%
# 'Country' 기준 그룹핑 수 값의 개수를 세어 'Goals' 기준 내림차순 정렬
df.groupby('Country').count().sort_values('Goals',ascending=False)
# Out:
#            Player  Goals  Years
# Country
# Brazil         81     81     81
# Germany        78     78     78
# Italy          60     60     60
# Argentina      59     59     59
# France         58     58     58
# ...           ...    ...    ...
# Haiti           1      1      1
# Angola          1      1      1
# Bolivia         1      1      1
# Israel          1      1      1
# Iraq            1      1      1
#
# [76 rows x 3 columns]

# %%
# 상위 5개 출력
df.groupby('Country').count().sort_values('Goals',ascending=False)[['Player']].head()
# Out:
#            Player
# Country
# Brazil         81
# Germany        78
# Italy          60
# Argentina      59
# France         58

# %% [markdown]
# ### Question 3
# Years 컬럼은 년도 -년도 형식으로 구성되어있고, 각 년도는 4자리 숫자이다. 년도 표기가 4자리 숫자로 안된 케이스가 존재한다. 해당 건은 몇건인지 출력하라

# %%
# 'Years' 컬럼 확인
df['Years']
# Out:
# 0       2002-2006-2010-2014
# 1            1998-2002-2006
# 2                 1970-1974
# 3                      1958
# 4       1958-1962-1966-1970
#                ...
# 1290                   1962
# 1291              1982-1990
# 1292                   1930
# 1293                   1930
# 1294              1954-1958
# Name: Years, Length: 1295, dtype: object

# %%
# 'Years' 컬럼을 문자열로 바꿔 '-' 기준으로 분리하고 'Year'컬럼에 저장
df['Year']=df['Years'].str.split('-')
df['Year']
# Out:
# 0       [2002, 2006, 2010, 2014]
# 1             [1998, 2002, 2006]
# 2                   [1970, 1974]
# 3                         [1958]
# 4       [1958, 1962, 1966, 1970]
#                   ...
# 1290                      [1962]
# 1291                [1982, 1990]
# 1292                      [1930]
# 1293                      [1930]
# 1294                [1954, 1958]
# Name: Year, Length: 1295, dtype: object

# %%
# 연도 표기가 4자리인지 확인하는 함수 check 생성
def check(list):
  for x in list:
    if len(str(x))!=4:
      return False
    else:
      return True

# 'Year' 컬럼에 check 함수 적용한 결과를 'check' 컬럼에 저장
df['check']=df['Year'].apply(check)
df['check']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1290    True
# 1291    True
# 1292    True
# 1293    True
# 1294    True
# Name: check, Length: 1295, dtype: bool

# %%
# 'check' 컬럼 값이 Fasle인 데이터(연도 표기가 4자리가 아닌 데이터) 확인
df[df['check']==False]
# Out:
#                     Player  Goals Years       Country Year  check
# 71             Roger Milla      5     0      Cameroon  [0]  False
# 190           Jesper Olsen      3     0       Denmark  [0]  False
# 210            Laszlo Kiss      3     0       Hungary  [0]  False
# 404         Ricardo Pelaez      2     0        Mexico  [0]  False
# 505          Djamel Zidane      1     0       Algeria  [0]  False
# 544         Andreas Herzog      1     0       Austria  [0]  False
# 622         Georgi Sokolov      1     0      Bulgaria  [0]  False
# 624           Eugene Ekeke      1     0      Cameroon  [0]  False
# 625             David Embe      1     0      Cameroon  [0]  False
# 640            Jose Sierra      1     0         Chile  [0]  False
# 651          Harold Lozano      1     0      Colombia  [0]  False
# 652        Leider Preciado      1     0      Colombia  [0]  False
# 662         Hernan Medford      1     0    Costa Rica  [0]  False
# ...

# %%
# 'check' 컬럼 값이 Fasle인 데이터(연도 표기가 4자리가 아닌 데이터)의 개수 구하기
len(df[df['check']==False])
# Out:
# 45

# %% [markdown]
# ### Question 4
# Q3에서 발생한 예외 케이스를 제외한 데이터프레임을 df2라고 정의하고 데이터의 행의 숫자를 출력하라 (아래 문제부터는 df2로 풀이하겠습니다)

# %%
# 'check' 컬럼의 값이 True인 데이터를 df2로 저장
df2=df[df['check']==True]
df2
# Out:
#                    Player  Goals                Years     Country  \
# 0          Miroslav Klose     16  2002-2006-2010-2014     Germany
# 1                 Ronaldo     15       1998-2002-2006      Brazil
# 2             Gerd Muller     14            1970-1974     Germany
# 3           Just Fontaine     13                 1958      France
# 4                    Pele     12  1958-1962-1966-1970      Brazil
# ...                   ...    ...                  ...         ...
# 1290        Josip Skoblar      1                 1962  Yugoslavia
# 1291          Safet Susic      1            1982-1990  Yugoslavia
# 1292  Aleksandar Tirnanic      1                 1930  Yugoslavia
# 1293  Djordje Vujadinovic      1                 1930  Yugoslavia
# 1294         Branko Zebec      1            1954-1958  Yugoslavia
#
#                           Year  check
# 0     [2002, 2006, 2010, 2014]   True
# 1           [1998, 2002, 2006]   True
# 2                 [1970, 1974]   True
# ...

# %%
# df2의 행의 갯수 확인
len(df2)
# Out:
# 1250

# %% [markdown]
# ### Question 5
# 월드컵 출전횟수를 나타내는 ‘LenCup’ 컬럼을 추가하고 4회 출전한 선수의 숫자를 구하여라

# %%
# 'Year' 컬럼의 길이를 'LenCup'으로 저장
df2['LenCup']=df2['Year'].str.len()
df2['LenCup']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       4
# 1       3
# 2       2
# 3       1
# 4       4
#        ..
# 1290    1
# 1291    2
# 1292    1
# 1293    1
# 1294    2
# Name: LenCup, Length: 1250, dtype: int64

# %%
# 빈도수 구하기
df2['LenCup'].value_counts()
# Out:
# 1    779
# 2    353
# 3    102
# 4     16
# Name: LenCup, dtype: int64

# %%
# 4인 데이터의 빈도수(=출전횟수가 4번인 데이터)
df2['LenCup'].value_counts()[4]
# Out:
# 16

# %% [markdown]
# ### Question 6
# Yugoslavia 국가의 월드컵 출전횟수가 2회인 선수들의 숫자를 구하여라

# %%
# Yugoslavia 국가의 데이터를 df2_Yugo 로 저장
df2_Yugo=df2[df2['Country']=='Yugoslavia']
df2_Yugo
# Out:
#                     Player  Goals           Years     Country  \
# 158        Drazen Jerkovic      4            1962  Yugoslavia
# 250          Dusan Bajevic      3            1974  Yugoslavia
# 251              Ivica Bek      3            1930  Yugoslavia
# 252            Milan Galic      3            1962  Yugoslavia
# 253      Robert Prosinecki      3  1990-1998-2002  Yugoslavia
# 254       Dragan Stojkovic      3       1990-1998  Yugoslavia
# 255       Toza Veselinovic      3            1958  Yugoslavia
# 491       Zeljko Cajkovski      2            1950  Yugoslavia
# 492            Davor Jozic      2            1990  Yugoslavia
# 493       Stanislav Karasi      2            1974  Yugoslavia
# 494   Slobodan Komljenovic      2            1998  Yugoslavia
# 495           Darko Pancev      2            1990  Yugoslavia
# 496   Aleksandar Petakovic      2            1958  Yugoslavia
# 497           Ivica Surjak      2       1974-1982  Yugoslavia
# ...

# %%
# 'LenCup'이 2인 데이터의 개수
(df2_Yugo['LenCup']==2).sum()
# Out:
# 7

# %% [markdown]
# ### Question 7
# 2002년도에 출전한 전체 선수는 몇명인가?

# %%
# 'Years'에 '2002'를 포함하고 있는 데이터 찾기
df2[df2['Years'].str.contains('2002')]
# Out:
#                  Player  Goals                Years    Country  \
# 0        Miroslav Klose     16  2002-2006-2010-2014    Germany
# 1               Ronaldo     15       1998-2002-2006     Brazil
# 7     Gabriel Batistuta     10       1994-1998-2002  Argentina
# 20      Christian Vieri      9            1998-2002      Italy
# 26              Rivaldo      8            1998-2002     Brazil
# ...                 ...    ...                  ...        ...
# 1231      Alvaro Recoba      1                 2002    Uruguay
# 1233    Dario Rodriguez      1                 2002    Uruguay
# 1244       Clint Mathis      1                 2002        USA
# 1246       John O Brien      1            2002-2006        USA
# 1247     Earnie Stewart      1       1994-1998-2002        USA
#
#                           Year  check  LenCup
# 0     [2002, 2006, 2010, 2014]   True       4
# 1           [1998, 2002, 2006]   True       3
# 7           [1994, 1998, 2002]   True       3
# ...

# %%
# 'Years'에 '2002'를 포함하고 있는 데이터의 개수
len(df2[df2['Years'].str.contains('2002')])
# Out:
# 156

# %% [markdown]
# ### Question 8
# 이름에 ‘carlos’ 단어가 들어가는 선수의 숫자는 몇 명인가? (대, 소문자 구분 x)

# %%
# 'Player' 컬럼의 문자열을 소문자로 바꿔 'carlos'가 포함되는 데이터 찾기
df2[df2['Player'].str.lower().str.contains('carlos')]
# Out:
#                    Player  Goals           Years    Country  \
# 150         Carlos Borges      4            1954    Uruguay
# 163       Carlos Peucelle      3            1930  Argentina
# 165          Carlos Tevez      3       2006-2010  Argentina
# 338        Carlos Tenorio      2       2002-2006    Ecuador
# 511      Carlos Babington      1            1974  Argentina
# 584        Carlos Alberto      1            1970     Brazil
# 589        Roberto Carlos      1  1998-2002-2006     Brazil
# 643          Carlos Vidal      1            1930      Chile
# 655     Carlos Valderrama      1  1990-1994-1998   Colombia
# 684       Carlos Oliveira      1            1938       Cuba
# 940           Carlos Vela      1            2018     Mexico
# 1041        Carlos Manuel      1            1986   Portugal
# 1151  Juan Carlos Valeron      1            2002      Spain
#
#                     Year  check  LenCup
# 150               [1954]   True       1
# 163               [1930]   True       1
# ...

# %%
# 'Player' 컬럼의 문자열을 소문자로 바꿔 'carlos'가 포함되는 데이터의 개수
len(df2[df2['Player'].str.lower().str.contains('carlos')])
# Out:
# 13

# %% [markdown]
# ### Question 9
# 월드컵 출전 횟수가 1회뿐인 선수들 중에서 가장 많은 득점을 올렸던 선수는 누구인가?

# %%
# 'LenCup'이 1인 데이터를 'Goals' 순으로 내림차순 정렬
df2[df2['LenCup']==1].sort_values('Goals',ascending=False)
# Out:
#                    Player  Goals Years     Country    Year  check  LenCup
# 3           Just Fontaine     13  1958      France  [1958]   True       1
# 6           Sandor Kocsis     11  1954     Hungary  [1954]   True       1
# 13                 Ademir      9  1950      Brazil  [1950]   True       1
# 21                Eusebio      9  1966    Portugal  [1966]   True       1
# 24      Guillermo Stabile      8  1930   Argentina  [1930]   True       1
# ...                   ...    ...   ...         ...     ...    ...     ...
# 758      Marcel Langiller      1  1930      France  [1930]   True       1
# 756       Oscar Heisserer      1  1938      France  [1938]   True       1
# 755        Gerard Hausser      1  1966      France  [1966]   True       1
# 754        Olivier Giroud      1  2014      France  [2014]   True       1
# 1293  Djordje Vujadinovic      1  1930  Yugoslavia  [1930]   True       1
#
# [779 rows x 7 columns]

# %%
# 'LenCup'이 1인 데이터를 'Goals' 순으로 내림차순 정렬하여 'Player' 확인
df2[df2['LenCup']==1].sort_values('Goals',ascending=False)['Player']
# Out:
# 3             Just Fontaine
# 6             Sandor Kocsis
# 13                   Ademir
# 21                  Eusebio
# 24        Guillermo Stabile
#                ...
# 758        Marcel Langiller
# 756         Oscar Heisserer
# 755          Gerard Hausser
# 754          Olivier Giroud
# 1293    Djordje Vujadinovic
# Name: Player, Length: 779, dtype: object

# %%
# 'LenCup'이 1인 데이터를 'Goals' 순으로 내림차순 정렬하여 'Player'의 첫번째 값 확인
df2[df2['LenCup']==1].sort_values('Goals',ascending=False)['Player'].values[0]
# Out:
# 'Just Fontaine'

# %% [markdown]
# ### Question 10
# 월드컵 출전횟수가 1회 뿐인 선수들이 가장 많은 국가는 어디인가?

# %%
# 'LenCup'이 1인 데이터를 'Country'로 그룹핑한 후 값의 개수 집계하여 LenCup1_Player로 저장
LenCup1_player=df2[df2['LenCup']==1].groupby('Country').count()
LenCup1_player
# Out:
#             Player  Goals  Years  Year  check  LenCup
# Country
# Algeria          6      6      6     6      6       6
# Angola           1      1      1     1      1       1
# Argentina       33     33     33    33     33      33
# Australia        2      2      2     2      2       2
# Austria         15     15     15    15     15      15
# ...            ...    ...    ...   ...    ...     ...
# USSR            21     21     21    21     21      21
# Ukraine          4      4      4     4      4       4
# Uruguay         26     26     26    26     26      26
# Wales            3      3      3     3      3       3
# Yugoslavia      30     30     30    30     30      30
#
# [75 rows x 6 columns]

# %%
# 'Player'가 'Player'의 최댓값과 같은 행 찾기
LenCup1_player.loc[LenCup1_player['Player']==(LenCup1_player['Player'].max())]
# Out:
#          Player  Goals  Years  Year  check  LenCup
# Country
# Brazil       43     43     43    43     43      43

# %%
# 'Player'가 'Player'의 최댓값과 같은 행의 index 확인
LenCup1_player.loc[LenCup1_player['Player']==(LenCup1_player['Player'].max())].index
# Out:
# Index(['Brazil'], dtype='object', name='Country')

# %%
# 'LenCup'이 1인 데이터의 'Country'의 빈도수 구하기
df2[df2['LenCup']==1]['Country'].value_counts()
# Out:
# Brazil       43
# Argentina    33
# Germany      32
# France       31
# Spain        30
#              ..
# Jamaica       1
# Haiti         1
# Panama        1
# Ecuador       1
# Togo          1
# Name: Country, Length: 75, dtype: int64

# %%
# 첫번째 인덱스 확인
df2[df2['LenCup']==1]['Country'].value_counts().index[0]
# Out:
# 'Brazil'
